# %% [markdown]
# ## Quick sort is an efficient sorting algorithm for many cases.
# The C programming language has a built-in quick sort algorithm that can sort all kinds of data via the qsort function.
#
# In order to be flexible, this function uses a lot of pointers.
#
# So far, we have seen pointers to simple types (e.g. int, float, double, char), and pointers to structures.  Now we will see a third type of pointer:  a pointer to a function.
#
# The prototype for the qsort function looks like:
#
# void
# qsort(void &#42;base, size_t nel, size_t width,
#     int (&#42;compar)(const void &#42;, const void &#42;));
#
# We can see from this that the qsort function doesn't return anything, but it takes 4 arguments.
#
# <ul>
# <li> base - is a pointer to an array of things you are trying to sort </li>
# <li> nel - is the number of elements that need to be sorted (i.e. the size of the array) </li>
# <li> width - is the width of an individual element in the array (i.e. sizeof(???)) </li>
# <li>compar - is a pointer to a function that is used to compare the elements in the array </li>
# </ul>
#
# (&#42;compar) makes it a pointer to a function.  If it said "int &#42;compar" it would be a function that returns a pointer to an integer.  The function takes two arguments (which are both generic (void) pointers), it returns an integer.
#
# The returned integer takes the following meanings:
# <ul>
# <li> &lt;0 - if the first argument is less than the second </li>
# <li> =0 - if the first argument is equal to the second </li>
# <li> &gt;0 - if the first argument is greater than the second </li>
# </ul>
#
# (Note that the strcmp function returns values just like this, so it is compatible with the qsort function.)
#
# Let's make an example.

# %%
# %%file qsort1.c
# #include <stdlib.h>
# #include <stdio.h>
#
# long int random();
#
# #define ARRAY_SIZE  20
#
# void print_array( int array[], int nel )
# {
#     int i;
#
#     for (i=0;i<nel;i++)
#         printf( "%d\n", array[i] );
#
# }
#
# void random_array( int array[], int nel )
# {
#     int i;
#
#     for (i=0;i<nel;i++)
#         array[i] = random() % 100;
# }
#
#
# int compar( const void *a, const void *b )
# {
#     const int *int_a, *int_b;
#
#     int_a = a;
#     int_b = b;
#
#     return -((*int_a)-(*int_b));
# }
#
# int main()
# {
#     int array[ARRAY_SIZE];
#
#     random_array( array, ARRAY_SIZE );
#     printf( "Before:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     printf("\n");
#
#     qsort( array, ARRAY_SIZE, sizeof(int), compar );
#     printf( "After:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     return 0;
# }
# Out:
# Overwriting qsort1.c

# %%
# %%bash
# gcc -ansi -Wall -pedantic qsort1.c -o qsort1

# %%
# %%bash
# ./qsort1
# Out:
# Before:
# 83
# 86
# 77
# 15
# 93
# 35
# 86
# 92
# 49
# 21
# 62
# 27
# 90
# 59
# 63
# 26
# 40
# 26
# 72
# 36
#
# After:
# 93
# 92
# 90
# 86
# 86
# 83
# 77
# 72
# 63
# 62
# 59
# 49
# 40
# 36
# 35
# 27
# 26
# 26
# 21
# 15

# %% [markdown]
# Ok. Let's see how this works for something other than numbers.  Let's work with names.
#
# There's a very cool website called http://listofrandomnames.com.  The example below comes from that web-site:

# %%
# %%file names.txt
# Juan Cookson
# Joy Falco
# Rosette Bradberry
# Idella Boeke
# Bridget Crites
# Toccara Krajewski
# Reginia Buell
# Amparo Abila
# Michell Nocera
# Tracee Brimer
# Pearl Corvin
# Hiedi Trexler
# Graham Loew
# Missy Haefner
# Jovita Killen
# Latrina Leiva
# Alexis Loose
# Danyelle Mari
# Trang Meas
# Kari Bradburn

# %%
# %%file qsort2.c
# #include <stdlib.h>
# #include <stdio.h>
# #include <string.h>
#
#
# #define ARRAY_SIZE  20
# #define STRING_SIZE  64
#
# void print_array( char array[ARRAY_SIZE][STRING_SIZE], int nel )
# {
#     int i;
#
#     for (i=0;i<nel;i++)
#         printf( "%s", array[i] );
#
# }
#
# void name_array( char array[ARRAY_SIZE][STRING_SIZE], int nel, int width )
# {
#     int i;
#     FILE *fp;
#
#     fp = fopen( "names.txt", "r" );
#     for (i=0;i<nel;i++)
#         fgets( array[i], width, fp );
#     fclose( fp );
# }
#
#
# int compar( const void *a, const void *b )
# {
#     const char *char_a, *char_b;
#
#     char_a = a;
#     char_b = b;
#
#     return strcmp(char_a,char_b);
# }
#
# int main()
# {
#     char array[ARRAY_SIZE][STRING_SIZE];
#
#     name_array( array, ARRAY_SIZE, STRING_SIZE );
#     printf( "Before:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     printf("\n");
#
#     qsort( array, ARRAY_SIZE, STRING_SIZE, compar );
#     printf( "After:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     return 0;
# }
# Out:
# Overwriting qsort2.c

# %%
# %%bash
# gcc -ansi -Wall -pedantic qsort2.c -o qsort2

# %%
# %%bash
# ./qsort2
# Out:
# Before:
# Juan Cookson
# Joy Falco
# Rosette Bradberry
# Idella Boeke
# Bridget Crites
# Toccara Krajewski
# Reginia Buell
# Amparo Abila
# Michell Nocera
# Tracee Brimer
# Pearl Corvin
# Hiedi Trexler
# Graham Loew
# Missy Haefner
# Jovita Killen
# Latrina Leiva
# Alexis Loose
# Danyelle Mari
# Trang Meas
# Kari Bradburn
#
# After:
# Alexis Loose
# Amparo Abila
# Bridget Crites
# Danyelle Mari
# Graham Loew
# Hiedi Trexler
# Idella Boeke
# Jovita Killen
# Joy Falco
# Juan Cookson
# Kari Bradburn
# Latrina Leiva
# Michell Nocera
# Missy Haefner
# Pearl Corvin
# Reginia Buell
# Rosette Bradberry
# Toccara Krajewski
# Tracee Brimer
# Trang Meas

# %% [markdown]
# (https://xkcd.com/327/)
#
# How about sorting structures?

# %%
# %%file qsort3.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# long int random();
#
# #define  ARRAY_SIZE   20
#
# struct order_struct {
#     char *name;
#     int cookie_boxes;
# };
#
# void print_array( struct order_struct order[], int nel )
# {
#     int i;
#
#     for (i=0;i<nel;i++)
#     {
#         printf( "%.32s %2d\n", order[i].name, order[i].cookie_boxes );
#     }
#
# }
#
# void order_array( struct order_struct order[], int nel )
# {
#     int i;
#     char name[64];
#     FILE *fp;
#
#     fp = fopen( "names.txt", "r" );
#     for (i=0;i<nel;i++)
#     {
#         fgets( name, 64, fp );
#         order[i].name = malloc( strlen(name)+1 );
#         strcpy( order[i].name, name );
#         order[i].cookie_boxes = random()%21;
#     }
#     fclose( fp );
# }
#
# int compar_name( const void *a, const void *b )
# {
#     const struct order_struct *struct_a, *struct_b;
#
#     struct_a = a;
#     struct_b = b;
#
#     return strcmp( struct_a->name, struct_b->name );
# }
#
# int compar_boxes( const void *a, const void *b )
# {
#     const struct order_struct *struct_a, *struct_b;
#
#     struct_a = a;
#     struct_b = b;
#
#     return -((struct_a->cookie_boxes)-(struct_b->cookie_boxes));
# }
#
# int main()
# {
#     struct order_struct array[ARRAY_SIZE];
#
#     order_array( array, ARRAY_SIZE );
#     printf( "Before:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     printf("\n");
#
#     qsort( array, ARRAY_SIZE, sizeof(struct order_struct), compar_name );
#     printf( "By name:\n" );
#     print_array( array, ARRAY_SIZE );
#
#     printf("\n");
#
#     qsort( array, ARRAY_SIZE, sizeof(struct order_struct), compar_boxes );
#     printf( "By boxes:\n" );
#     print_array( array, ARRAY_SIZE );
#     return 0;
# }
# Out:
# Overwriting qsort3.c

# %%
# %%bash
# gcc -ansi -Wall -pedantic qsort3.c -o qsort3

# %%
# %%bash
# ./qsort3
# Out:
# Before:
# Juan Cookson
#   1
# Joy Falco
#   4
# Rosette Bradberry
#   9
# Idella Boeke
#  19
# Bridget Crites
#   8
# Toccara Krajewski
#  10
# Reginia Buell
#  10
# Amparo Abila
#   9
# Michell Nocera
#  15
# Tracee Brimer
#  10
# Pearl Corvin
#   2
# Hiedi Trexler
#  19
# Graham Loew
#  20
# Missy Haefner
#   4
# Jovita Killen
#  20
# Latrina Leiva
#   7
# Alexis Loose
#   3
# Danyelle Mari
#  15
# Trang Meas
#  16
# Kari Bradburn
#  16
#
# By name:
# Alexis Loose
#   3
# Amparo Abila
#   9
# Bridget Crites
#   8
# Danyelle Mari
#  15
# Graham Loew
#  20
# Hiedi Trexler
#  19
# Idella Boeke
#  19
# Jovita Killen
#  20
# Joy Falco
#   4
# Juan Cookson
#   1
# Kari Bradburn
#  16
# Latrina Leiva
#   7
# Michell Nocera
#  15
# Missy Haefner
#   4
# Pearl Corvin
#   2
# Reginia Buell
#  10
# Rosette Bradberry
#   9
# Toccara Krajewski
#  10
# Tracee Brimer
#  10
# Trang Meas
#  16
#
# By boxes:
# Graham Loew
#  20
# Jovita Killen
#  20
# Hiedi Trexler
#  19
# Idella Boeke
#  19
# Kari Bradburn
#  16
# Trang Meas
#  16
# Danyelle Mari
#  15
# Michell Nocera
#  15
# Reginia Buell
#  10
# Toccara Krajewski
#  10
# Tracee Brimer
#  10
# Amparo Abila
#   9
# Rosette Bradberry
#   9
# Bridget Crites
#   8
# Latrina Leiva
#   7
# Joy Falco
#   4
# Missy Haefner
#   4
# Alexis Loose
#   3
# Pearl Corvin
#   2
# Juan Cookson
#   1

# %%
# %%file qsort4.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# long int random();
#
# #define  ARRAY_SIZE   20
#
# struct order_struct {
#     char *name;
#     int cookie_boxes;
# };
#
# void print_array( struct order_struct *ptrs[], int nel )
# {
#     int i;
#
#     for (i=0;i<nel;i++)
#     {
#         printf( "%.32s %2d\n", ptrs[i]->name, ptrs[i]->cookie_boxes );
#     }
#
# }
#
# void order_array( struct order_struct order[], int nel )
# {
#     int i;
#     char name[64];
#     FILE *fp;
#
#     fp = fopen( "names.txt", "r" );
#     for (i=0;i<nel;i++)
#     {
#         fgets( name, 64, fp );
#         order[i].name = malloc( strlen(name)+1 );
#         strcpy( order[i].name, name );
#         order[i].cookie_boxes = random()%21;
#     }
#     fclose( fp );
# }
#
#
# int compar_name( const void *a, const void *b )
# {
#     struct order_struct * const *struct_a;
#     struct order_struct * const *struct_b;
#
#     struct_a = a;
#     struct_b = b;
#
#     return strcmp( (*struct_a)->name, (*struct_b)->name );
# }
#
# int compar_boxes( const void *a, const void *b )
# {
#     struct order_struct * const *struct_a, * const *struct_b;
#
#     struct_a = a;
#     struct_b = b;
#
#     return -(((*struct_a)->cookie_boxes)-((*struct_b)->cookie_boxes));
# }
#
# int main()
# {
#     struct order_struct array[ARRAY_SIZE];
#     struct order_struct *ptrs[ARRAY_SIZE];
#
#     int i;
#
#
#     order_array( array, ARRAY_SIZE );
#
#     for (i=0;i<ARRAY_SIZE;i++)
#     {
#         ptrs[i] = &(array[i]);
#         /*ptrs[i] = array+i;*/
#     }
#
#
#
#     printf( "Before:\n" );
#     print_array( ptrs, ARRAY_SIZE );
#     printf("\n");
#
#     qsort( ptrs, ARRAY_SIZE, sizeof(struct order_struct *), compar_name );
#     printf( "By name:\n" );
#     print_array( ptrs, ARRAY_SIZE );
#
#     printf("\n");
#
#     qsort( ptrs, ARRAY_SIZE, sizeof(struct order_struct *), compar_boxes );
#     printf( "By boxes:\n" );
#     print_array( ptrs, ARRAY_SIZE );
#     return 0;
# }
# Out:
# Overwriting qsort4.c

# %%
# %%bash
# gcc -ansi -Wall -pedantic qsort4.c -o qsort4

# %%
# %%bash
# ./qsort4
# Out:
# Before:
# Juan Cookson
#   1
# Joy Falco
#   4
# Rosette Bradberry
#   9
# Idella Boeke
#  19
# Bridget Crites
#   8
# Toccara Krajewski
#  10
# Reginia Buell
#  10
# Amparo Abila
#   9
# Michell Nocera
#  15
# Tracee Brimer
#  10
# Pearl Corvin
#   2
# Hiedi Trexler
#  19
# Graham Loew
#  20
# Missy Haefner
#   4
# Jovita Killen
#  20
# Latrina Leiva
#   7
# Alexis Loose
#   3
# Danyelle Mari
#  15
# Trang Meas
#  16
# Kari Bradburn
#  16
#
# By name:
# Alexis Loose
#   3
# Amparo Abila
#   9
# Bridget Crites
#   8
# Danyelle Mari
#  15
# Graham Loew
#  20
# Hiedi Trexler
#  19
# Idella Boeke
#  19
# Jovita Killen
#  20
# Joy Falco
#   4
# Juan Cookson
#   1
# Kari Bradburn
#  16
# Latrina Leiva
#   7
# Michell Nocera
#  15
# Missy Haefner
#   4
# Pearl Corvin
#   2
# Reginia Buell
#  10
# Rosette Bradberry
#   9
# Toccara Krajewski
#  10
# Tracee Brimer
#  10
# Trang Meas
#  16
#
# By boxes:
# Graham Loew
#  20
# Jovita Killen
#  20
# Hiedi Trexler
#  19
# Idella Boeke
#  19
# Kari Bradburn
#  16
# Trang Meas
#  16
# Danyelle Mari
#  15
# Michell Nocera
#  15
# Reginia Buell
#  10
# Toccara Krajewski
#  10
# Tracee Brimer
#  10
# Amparo Abila
#   9
# Rosette Bradberry
#   9
# Bridget Crites
#   8
# Latrina Leiva
#   7
# Joy Falco
#   4
# Missy Haefner
#   4
# Alexis Loose
#   3
# Pearl Corvin
#   2
# Juan Cookson
#   1
